# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
import scipy
from PIL import Image
from scipy import ndimage
# %matplotlib inline

# Load data from files

train_dataset = h5py.File('train_catvnoncat.h5', "r")
test_dataset = h5py.File('test_catvnoncat.h5', "r")

# Split into x and y

train_X = np.array(train_dataset["train_set_x"][:])
train_Y = np.array(train_dataset["train_set_y"][:])
test_X = np.array(test_dataset["test_set_x"][:])
test_Y = np.array(test_dataset["test_set_y"][:])
classes = np.array(test_dataset["list_classes"][:])

# %%
# Flatten images and normalize pixel values

train_X_flat = (train_X.reshape(train_X.shape[0], -1)/255).T
test_X_flat = (test_X.reshape(test_X.shape[0], -1)/255).T

# %%
# Define sigmoid function

def sigmoid(z):
    return 1/(1+np.exp(-z))

# %%
# Initialize variables and set parameters

X = train_X_flat
Y = train_Y
w = np.zeros((train_X_flat.shape[0],1))
b = 0
num_iterations = 1000
learning_rate = 0.6

# Perform training

for i in range(num_iterations):

    # Save length of X
    m = X.shape[1]
    
    # Calculate sigmoid value and cost given current weights and biases
    A = sigmoid(np.dot(w.T,X) + b)
    cost = np.sum(((- np.log(A))*Y + (-np.log(1-A))*(1-Y)))/m

    # Calculate gradients
    dw = (np.dot(X,(A-Y).T))/m
    db = (np.sum(A-Y))/m

    # Convert cost to scalar
    cost = np.squeeze(cost)
    
    # Take a gradient step
    w = w - (learning_rate*dw)
    b = b - (learning_rate*db)

    if (i % 5 == 4):
        print(f"After {i+1} iterations, the cost is {cost}")

print(f"The final weights are {w}")
print(f"The final bias is {b}")
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_19356\754706473.py:19: RuntimeWarning: divide by zero encountered in log
#   cost = np.sum(((- np.log(A))*Y + (-np.log(1-A))*(1-Y)))/m
# C:\Users\thoma\AppData\Local\Temp\ipykernel_19356\754706473.py:19: RuntimeWarning: invalid value encountered in multiply
#   cost = np.sum(((- np.log(A))*Y + (-np.log(1-A))*(1-Y)))/m
# C:\Users\thoma\AppData\Local\Temp\ipykernel_19356\1015999558.py:4: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-z))
# After 5 iterations, the cost is 36.73481218011037
# After 10 iterations, the cost is 138.4541968361913
# After 15 iterations, the cost is nan
# After 20 iterations, the cost is nan
# After 25 iterations, the cost is 43.12464727104529
# After 30 iterations, the cost is nan
# After 35 iterations, the cost is nan
# After 40 iterations, the cost is 35.50070105492921
# After 45 iterations, the cost is nan
# After 50 iterations, the cost is nan
# After 55 iterations, the cost is nan
# After 60 iterations, the cost is nan
# After 65 iterations, the cost is nan
# After 70 iterations, the cost is nan
# After 75 iterations, the cost is nan
# After 80 iterations, the cost is nan
# After 85 iterations, the cost is nan
# After 90 iterations, the cost is nan
# After 95 iterations, the cost is nan
# After 100 iterations, the cost is nan
# After 105 iterations, the cost is nan
# After 110 iterations, the cost is nan
# After 115 iterations, the cost is nan
# After 120 iterations, the cost is nan
# After 125 iterations, the cost is nan
# After 130 iterations, the cost is nan
# After 135 iterations, the cost is nan
# After 140 iterations, the cost is nan
# After 145 iterations, the cost is nan
# After 150 iterations, the cost is nan
# After 155 iterations, the cost is nan
# After 160 iterations, the cost is nan
# After 165 iterations, the cost is nan
# After 170 iterations, the cost is nan
# After 175 iterations, the cost is nan
# After 180 iterations, the cost is nan
# After 185 iterations, the cost is nan
# After 190 iterations, the cost is nan
# After 195 iterations, the cost is nan
# After 200 iterations, the cost is nan
# After 205 iterations, the cost is nan
# After 210 iterations, the cost is nan
# After 215 iterations, the cost is nan
# After 220 iterations, the cost is nan
# After 225 iterations, the cost is nan
# After 230 iterations, the cost is nan
# After 235 iterations, the cost is nan
# After 240 iterations, the cost is nan
# After 245 iterations, the cost is nan
# After 250 iterations, the cost is nan
# After 255 iterations, the cost is nan
# After 260 iterations, the cost is nan
# After 265 iterations, the cost is nan
# After 270 iterations, the cost is nan
# After 275 iterations, the cost is nan
# After 280 iterations, the cost is nan
# After 285 iterations, the cost is nan
# After 290 iterations, the cost is nan
# After 295 iterations, the cost is nan
# After 300 iterations, the cost is nan
# After 305 iterations, the cost is nan
# After 310 iterations, the cost is nan
# After 315 iterations, the cost is nan
# After 320 iterations, the cost is nan
# After 325 iterations, the cost is nan
# After 330 iterations, the cost is nan
# After 335 iterations, the cost is nan
# After 340 iterations, the cost is nan
# After 345 iterations, the cost is nan
# After 350 iterations, the cost is nan
# After 355 iterations, the cost is nan
# After 360 iterations, the cost is nan
# After 365 iterations, the cost is nan
# After 370 iterations, the cost is nan
# After 375 iterations, the cost is nan
# After 380 iterations, the cost is nan
# After 385 iterations, the cost is nan
# After 390 iterations, the cost is nan
# After 395 iterations, the cost is nan
# After 400 iterations, the cost is nan
# After 405 iterations, the cost is nan
# After 410 iterations, the cost is nan
# After 415 iterations, the cost is nan
# After 420 iterations, the cost is nan
# After 425 iterations, the cost is nan
# After 430 iterations, the cost is nan
# After 435 iterations, the cost is nan
# After 440 iterations, the cost is nan
# After 445 iterations, the cost is nan
# After 450 iterations, the cost is nan
# After 455 iterations, the cost is nan
# After 460 iterations, the cost is nan
# After 465 iterations, the cost is nan
# After 470 iterations, the cost is nan
# After 475 iterations, the cost is nan
# After 480 iterations, the cost is nan
# After 485 iterations, the cost is nan
# After 490 iterations, the cost is nan
# After 495 iterations, the cost is nan
# After 500 iterations, the cost is nan
# After 505 iterations, the cost is nan
# After 510 iterations, the cost is nan
# After 515 iterations, the cost is nan
# After 520 iterations, the cost is nan
# After 525 iterations, the cost is nan
# After 530 iterations, the cost is nan
# After 535 iterations, the cost is nan
# After 540 iterations, the cost is nan
# After 545 iterations, the cost is nan
# After 550 iterations, the cost is nan
# After 555 iterations, the cost is nan
# After 560 iterations, the cost is nan
# After 565 iterations, the cost is nan
# After 570 iterations, the cost is nan
# After 575 iterations, the cost is nan
# After 580 iterations, the cost is nan
# After 585 iterations, the cost is nan
# After 590 iterations, the cost is nan
# After 595 iterations, the cost is nan
# After 600 iterations, the cost is nan
# After 605 iterations, the cost is nan
# After 610 iterations, the cost is nan
# After 615 iterations, the cost is nan
# After 620 iterations, the cost is nan
# After 625 iterations, the cost is nan
# After 630 iterations, the cost is nan
# After 635 iterations, the cost is nan
# After 640 iterations, the cost is nan
# After 645 iterations, the cost is nan
# After 650 iterations, the cost is nan
# After 655 iterations, the cost is nan
# After 660 iterations, the cost is nan
# After 665 iterations, the cost is nan
# After 670 iterations, the cost is nan
# After 675 iterations, the cost is nan
# After 680 iterations, the cost is nan
# After 685 iterations, the cost is nan
# After 690 iterations, the cost is nan
# After 695 iterations, the cost is nan
# After 700 iterations, the cost is nan
# After 705 iterations, the cost is nan
# After 710 iterations, the cost is nan
# After 715 iterations, the cost is nan
# After 720 iterations, the cost is nan
# After 725 iterations, the cost is nan
# After 730 iterations, the cost is nan
# After 735 iterations, the cost is nan
# After 740 iterations, the cost is nan
# After 745 iterations, the cost is nan
# After 750 iterations, the cost is nan
# After 755 iterations, the cost is nan
# After 760 iterations, the cost is nan
# After 765 iterations, the cost is nan
# After 770 iterations, the cost is nan
# After 775 iterations, the cost is nan
# After 780 iterations, the cost is nan
# After 785 iterations, the cost is nan
# After 790 iterations, the cost is nan
# After 795 iterations, the cost is nan
# After 800 iterations, the cost is nan
# After 805 iterations, the cost is nan
# After 810 iterations, the cost is nan
# After 815 iterations, the cost is nan
# After 820 iterations, the cost is nan
# After 825 iterations, the cost is nan
# After 830 iterations, the cost is nan
# After 835 iterations, the cost is nan
# After 840 iterations, the cost is nan
# After 845 iterations, the cost is nan
# After 850 iterations, the cost is nan
# After 855 iterations, the cost is nan
# After 860 iterations, the cost is nan
# After 865 iterations, the cost is nan
# After 870 iterations, the cost is nan
# After 875 iterations, the cost is nan
# After 880 iterations, the cost is nan
# After 885 iterations, the cost is nan
# After 890 iterations, the cost is nan
# After 895 iterations, the cost is nan
# After 900 iterations, the cost is nan
# After 905 iterations, the cost is nan
# After 910 iterations, the cost is nan
# After 915 iterations, the cost is nan
# After 920 iterations, the cost is nan
# After 925 iterations, the cost is nan
# After 930 iterations, the cost is nan
# After 935 iterations, the cost is nan
# After 940 iterations, the cost is nan
# After 945 iterations, the cost is nan
# After 950 iterations, the cost is nan
# After 955 iterations, the cost is nan
# After 960 iterations, the cost is nan
# After 965 iterations, the cost is nan
# After 970 iterations, the cost is nan
# After 975 iterations, the cost is nan
# After 980 iterations, the cost is nan
# After 985 iterations, the cost is nan
# After 990 iterations, the cost is nan
# After 995 iterations, the cost is nan
# After 1000 iterations, the cost is nan
# The final weights are [[ 0.54256536]
#  [-1.25829429]
#  [-0.58826006]
#  ...
#  [-0.49313579]
#  [-1.32521296]
#  [ 1.18685455]]
# The final bias is 0.7962820225462589

# %%
# Compute predicted values
A = sigmoid(np.dot(w.T,test_X_flat) + b)
Y_predict_test = (A >= 0.5) * 1.0
Y_predict_train = sigmoid(np.dot(w.T,X) + b)

# Compute prediction accuracy
print(f"train accuracy: {1-np.mean(np.abs(Y_predict_train - train_Y)):2f}")
print(f"test accuracy: {1-np.mean(np.abs(Y_predict_test - test_Y)):2f}")
# Out:
# train accuracy: 0.999820
# test accuracy: 0.740000

# %%
indices = []

# Add indices of incorrect predictions to list

for i in range(len(Y_predict_test[0])):
    if (Y_predict_test[0][i] != test_Y[i]):
        indices.append(i)

print(indices)
# Out:
# [5, 6, 10, 18, 19, 28, 29, 30, 33, 34, 41, 44, 46]

# %%
# create figure
fig = plt.figure(figsize=(10, 7))

# set number of rows and columns in figure
rows = 3
columns = 5

k = 1
for i in indices:
    fig.add_subplot(rows, columns, k) # i - 54 is the subplot indices, 1,2,3,4
    plt.imshow(test_X[i])
    plt.axis('off')
    k += 1
